# %%
! git clone https://gitlab.cc-asp.fraunhofer.de/wxu/my-anfis-pytorch.git
# Out:
# Cloning into 'my-anfis-pytorch'...
# remote: Enumerating objects: 552, done.
# remote: Total 552 (delta 0), reused 0 (delta 0), pack-reused 552
# Receiving objects: 100% (552/552), 69.85 MiB | 1.22 MiB/s, done.
# Resolving deltas: 100% (117/117), done.

# %%
# !pip install torch==1.8.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 735.5 MB 16 kB/s
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.0+cu116
#     Uninstalling torch-1.13.0+cu116:
#       Successfully uninstalled torch-1.13.0+cu116
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.14.0+cu116 requires torch==1.13.0, but you have torch 1.8.0 which is incompatible.
# torchtext 0.14.0 requires torch==1.13.0, but you have torch 1.8.0 which is incompatible.
# torchaudio 0.13.0+cu116 requires torch==1.13.0, but you have torch 1.8.0 which is incompatible.
# ...

# %%
import torch
torch.__version__
# Out:
# '1.8.0'

# %%
! python /content/my-anfis-pytorch/my_anfis.py
# Out:
# norm: tensor([5.0005e-05, 5.4754e-66, 2.3703e-04, 1.2849e-32, 9.9969e-01, 4.3543e-12,
#         2.6467e-05, 1.1701e-07], dtype=torch.float64, grad_fn=<SelectBackward>)
# raw: tensor([1.5563e-12, 1.7041e-73, 7.3773e-12, 3.9992e-40, 3.1113e-08, 1.3552e-19,
#         8.2373e-13, 3.6419e-15], dtype=torch.float64, grad_fn=<SelectBackward>)
# ### Testing for 800 cases
# Cross Entropy = 0.3143, accuracy = 0.9325
# Figure(640x480)
# Validation total accuracy: 96.423%
# Figure(640x480)
# Validation total accuracy: 96.467%

# %%
! python /content/my-anfis-pytorch/jang_examples.py
# Out:
# Example 1 from Jang's paper
# Figure(640x480)
# Figure(640x480)
# ### Training for 20 epochs, training size = 121 cases, test size = 9
# epoch 0: Train rmse=0.10498, Test rmse=0.26764
# Current LR: 0.001
# -----------------
# epoch 1: Train rmse=0.10496, Test rmse=0.26755
# Current LR: 0.001
# -----------------
# epoch 2: Train rmse=0.10494, Test rmse=0.26744
# Current LR: 0.001
# -----------------
# epoch 3: Train rmse=0.10491, Test rmse=0.26733
# Current LR: 0.001
# -----------------
# epoch 4: Train rmse=0.10489, Test rmse=0.26722
# Current LR: 0.001
# -----------------
# epoch 5: Train rmse=0.10486, Test rmse=0.26710
# Current LR: 0.001
# -----------------
# epoch 6: Train rmse=0.10484, Test rmse=0.26699
# Current LR: 0.001
# -----------------
# epoch 7: Train rmse=0.10481, Test rmse=0.26687
# Current LR: 0.001
# -----------------
# epoch 8: Train rmse=0.10479, Test rmse=0.26675
# Current LR: 0.001
# -----------------
# epoch 9: Train rmse=0.10476, Test rmse=0.26663
# ...

# %%
! python /content/my-anfis-pytorch/jang_examples.py
# Out:
# Example 2 from Jang's paper
# ### Training for 200 epochs, training size = 216 cases
# epoch    0: MSE=0.36651, RMSE=0.60540 =4.12%
# epoch   10: MSE=0.01686, RMSE=0.12987 =0.95%
# epoch   20: MSE=0.00566, RMSE=0.07521 =0.55%
# epoch   30: MSE=0.01632, RMSE=0.12775 =0.92%
# epoch   40: MSE=0.00856, RMSE=0.09253 =0.67%
# epoch   50: MSE=0.00914, RMSE=0.09562 =0.68%
# epoch   60: MSE=0.00795, RMSE=0.08916 =0.64%
# epoch   70: MSE=0.00595, RMSE=0.07713 =0.58%
# epoch   80: MSE=0.00581, RMSE=0.07619 =0.58%
# epoch   90: MSE=0.00596, RMSE=0.07720 =0.59%
# epoch  100: MSE=0.00575, RMSE=0.07582 =0.58%
# epoch  110: MSE=0.00541, RMSE=0.07356 =0.56%
# epoch  120: MSE=0.00530, RMSE=0.07282 =0.56%
# epoch  130: MSE=0.00522, RMSE=0.07222 =0.55%
# epoch  140: MSE=0.00514, RMSE=0.07169 =0.55%
# epoch  150: MSE=0.00497, RMSE=0.07051 =0.55%
# epoch  160: MSE=0.00474, RMSE=0.06886 =0.53%
# epoch  170: MSE=0.00455, RMSE=0.06744 =0.52%
# epoch  180: MSE=0.00454, RMSE=0.06736 =0.52%
# ...

# %%
! python /content/my-anfis-pytorch/jang_examples.py
# Out:
# Example 3 from Jang's paper
# ### Training for 500 epochs, training size = 101 cases
# epoch    0: MSE=0.00254, RMSE=0.05044 =341216903473019.25%
# epoch   10: MSE=0.00052, RMSE=0.02280 =75276649661162.17%
# epoch   20: MSE=0.00140, RMSE=0.03744 =193520492560828.47%
# epoch   30: MSE=0.00073, RMSE=0.02699 =47869829657798.49%
# epoch   40: MSE=0.00043, RMSE=0.02070 =57676333617827.32%
# epoch   50: MSE=0.00038, RMSE=0.01941 =150335262809057.34%
# epoch   60: MSE=0.00013, RMSE=0.01147 =33930989309844.00%
# epoch   70: MSE=0.00041, RMSE=0.02017 =146785647788629.38%
# epoch   80: MSE=0.00044, RMSE=0.02093 =219534825520476.75%
# epoch   90: MSE=0.00008, RMSE=0.00873 =90342965431055.17%
# epoch  100: MSE=0.00004, RMSE=0.00641 =18947206843860.84%
# epoch  110: MSE=0.00003, RMSE=0.00571 =16983973886707.84%
# epoch  120: MSE=0.00007, RMSE=0.00834 =32722265544107.71%
# epoch  130: MSE=0.00006, RMSE=0.00797 =12651384600472.79%
# epoch  140: MSE=0.00008, RMSE=0.00868 =49240165986538.27%
# ...

# %%
# %cp -av /content/my-anfis-pytorch /content/drive/MyDrive/ANFIS_Pytorch
# Out:
# '/content/my-anfis-pytorch' -> '/content/drive/MyDrive/ANFIS_Pytorch/my-anfis-pytorch'
# '/content/my-anfis-pytorch/.gitignore' -> '/content/drive/MyDrive/ANFIS_Pytorch/my-anfis-pytorch/.gitignore'
# '/content/my-anfis-pytorch/.idea' -> '/content/drive/MyDrive/ANFIS_Pytorch/my-anfis-pytorch/.idea'
# '/content/my-anfis-pytorch/.idea/.gitignore' -> '/content/drive/MyDrive/ANFIS_Pytorch/my-anfis-pytorch/.idea/.gitignore'
# '/content/my-anfis-pytorch/Anfis-vignette.pdf' -> '/content/drive/MyDrive/ANFIS_Pytorch/my-anfis-pytorch/Anfis-vignette.pdf'
# '/content/my-anfis-pytorch/LICENSE' -> '/content/drive/MyDrive/ANFIS_Pytorch/my-anfis-pytorch/LICENSE'
# '/content/my-anfis-pytorch/README.md' -> '/content/drive/MyDrive/ANFIS_Pytorch/my-anfis-pytorch/README.md'
# '/content/my-anfis-pytorch/anfis.py' -> '/content/drive/MyDrive/ANFIS_Pytorch/my-anfis-pytorch/anfis.py'
# '/content/my-anfis-pytorch/cluster_data' -> '/content/drive/MyDrive/ANFIS_Pytorch/my-anfis-pytorch/cluster_data'
# ...
